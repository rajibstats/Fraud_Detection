# %%
# Import general useful packages
import numpy as np
import pandas as pd

# Import matplotlib for visualisations
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# label encoding the data 
from sklearn.preprocessing import LabelEncoder

# Import all machine learning algorithms
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb

# Import other useful subpackage
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-69-de18d6397704> in <module>()
#      16 from sklearn.ensemble import RandomForestClassifier
#      17 from sklearn.ensemble import GradientBoostingClassifier
# ---> 18 import xgboost as xgb
#      19
#      20 # Import other useful subpackage
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
data_1 = pd.read_csv('C:\\Users\\Purnendu\\Desktop\\R Code\\Python\\Fraud Detection\\data.csv')

# %%
# For training data
print("data_1: {}".format(data_1.shape))
print("Null values present in fraud data: {}".format(data_1.isnull().values.any()))
## Output:
# Training Data: (5000, 71)
# Null values present in training data: False
# Out:
# data_1: (5000, 71)
# Null values present in fraud data: False

# %%
data_1.head(5)
# Out:
#         f1     f2   f3  f4     f5  f6     f7  f8      f9    f10  ...    f62  \
# 0     true  False   No   1  False   1  False   1  type_A  False  ...      0
# 1     true  False   No   1  False   1  False   1  type_A  False  ...      0
# 2  no_data  False  Yes   1   True   1  False   1  type_A  False  ...      0
# 3    false  False  Yes   1   True   1  False   1  type_A  False  ...      0
# 4     true  False  Yes   1   True   1  False   1  type_A  False  ...      0
#
#    f63 f64    f65    f66        f67 f68    f69                date_time  class
# 0    0   1  false  False  not_valid   1  160.0  2017-04-18T09:17:44.231      0
# 1    0   1  false  False  not_valid   1  159.0  2017-04-08T05:56:06.599      0
# 2    0   1  false   True  not_valid   1  118.0  2017-05-02T16:28:43.207      0
# 3    0   1  false  False  not_valid   1  155.0  2017-05-17T06:48:45.574      0
# 4    0   1  false   True  not_valid   1  125.0  2017-05-09T18:53:05.890      0
#
# [5 rows x 71 columns]

# %%
# Univariate Analysis
data_1.describe()
# Out:
#                 f4           f6           f8          f18          f20  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean      1.243600     1.155400     1.754200     1.074800     1.272000
# std       1.080228     0.767964     1.925753     0.336493     0.631265
# min       1.000000     0.000000     1.000000     1.000000     1.000000
# 25%       1.000000     1.000000     1.000000     1.000000     1.000000
# 50%       1.000000     1.000000     1.000000     1.000000     1.000000
# 75%       1.000000     1.000000     2.000000     1.000000     1.000000
# max      47.000000    36.000000    69.000000     5.000000    12.000000
#
#                f21          f23          f25          f26          f27  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean    548.471622     8.411000     1.101400     1.319600     1.249600
# std     888.582893    21.468457     0.666038     0.912153     4.793819
# ...

# %%
# label encoding the data 
le = LabelEncoder() 
  
data_1['f1']= le.fit_transform(data_1['f1']) 
data_1['f2']= le.fit_transform(data_1['f2'])
data_1['f3']= le.fit_transform(data_1['f3'])
data_1['f5']= le.fit_transform(data_1['f5'])
data_1['f7']= le.fit_transform(data_1['f7'])
data_1['f9']= le.fit_transform(data_1['f9'])
data_1['f10']= le.fit_transform(data_1['f10'])
data_1['f11']= le.fit_transform(data_1['f11'])
data_1['f12']= le.fit_transform(data_1['f12'])
data_1['f15']= le.fit_transform(data_1['f15'])
data_1['f16']= le.fit_transform(data_1['f16'])
data_1['f17']= le.fit_transform(data_1['f17'])
data_1['f19']= le.fit_transform(data_1['f19'])
data_1['f22']= le.fit_transform(data_1['f22'])
data_1['f24']= le.fit_transform(data_1['f24'])
data_1['f28']= le.fit_transform(data_1['f28'])
data_1['f29']= le.fit_transform(data_1['f29'])
data_1['f31']= le.fit_transform(data_1['f31'])
data_1['f32']= le.fit_transform(data_1['f32'])
data_1['f33']= le.fit_transform(data_1['f33'])
data_1['f34']= le.fit_transform(data_1['f34'])
data_1['f35']= le.fit_transform(data_1['f35'])
data_1['f37']= le.fit_transform(data_1['f37'])
data_1['f38']= le.fit_transform(data_1['f38'])
data_1['f39']= le.fit_transform(data_1['f39'])
data_1['f40']= le.fit_transform(data_1['f40'])
data_1['f41']= le.fit_transform(data_1['f41'])
data_1['f42']= le.fit_transform(data_1['f42'])
data_1['f43']= le.fit_transform(data_1['f43'])
data_1['f44']= le.fit_transform(data_1['f44'])
data_1['f45']= le.fit_transform(data_1['f45'])
data_1['f46']= le.fit_transform(data_1['f46'])
data_1['f49']= le.fit_transform(data_1['f49'])
data_1['f50']= le.fit_transform(data_1['f50'])
data_1['f51']= le.fit_transform(data_1['f51'])
data_1['f53']= le.fit_transform(data_1['f53'])
data_1['f54']= le.fit_transform(data_1['f54'])
data_1['f56']= le.fit_transform(data_1['f56'])
data_1['f57']= le.fit_transform(data_1['f57'])
data_1['f59']= le.fit_transform(data_1['f59'])
data_1['f60']= le.fit_transform(data_1['f60'])
data_1['f61']= le.fit_transform(data_1['f61'])
data_1['f65']= le.fit_transform(data_1['f65'])
data_1['f66']= le.fit_transform(data_1['f66'])
data_1['f67']= le.fit_transform(data_1['f67'])

# %%
#See the value after one hot ecdoing
data_1.head(5)
# Out:
#    f1  f2  f3  f4  f5  f6  f7  f8  f9  f10  ...    f62  f63 f64 f65  f66  f67  \
# 0   2   0   0   1   0   1   0   1   0    0  ...      0    0   1   0    0    1
# 1   2   0   0   1   0   1   0   1   0    0  ...      0    0   1   0    0    1
# 2   1   0   1   1   1   1   0   1   0    0  ...      0    0   1   0    1    1
# 3   0   0   1   1   1   1   0   1   0    0  ...      0    0   1   0    0    1
# 4   2   0   1   1   1   1   0   1   0    0  ...      0    0   1   0    1    1
#
#    f68    f69                date_time  class
# 0    1  160.0  2017-04-18T09:17:44.231      0
# 1    1  159.0  2017-04-08T05:56:06.599      0
# 2    1  118.0  2017-05-02T16:28:43.207      0
# 3    1  155.0  2017-05-17T06:48:45.574      0
# 4    1  125.0  2017-05-09T18:53:05.890      0
#
# [5 rows x 71 columns]

# %%
# Get X and Y from data_1
x = data_1['class']
y = data_1.drop(columns = ['class','date_time'])

# Splitting the X and Y into the 
# Training set and Testing set 
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state = 123)

# %%
accuacy_scores = np.zeros(6)

#Support Vector classifier
clf = SVC().fit(x_train,y_train)
prediction = clf.predict(x_test)
accuracy_scores[0] = accuracy_score(y_test, prediction) * 100
print('Support Vector Classifier Accuracy: {}%'.format(accuracy_scores[0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-b09e74c44207> in <module>()
#       2 from sklearn.svm import SVC
#       3 #Support Vector classifier
# ----> 4 clf = SVC().fit(x_train,y_train)
#       5 prediction = clf.predict(x_test)
#       6 accuracy_scores[0] = accuracy_score(y_test, prediction) * 100
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# ...

# %%
# Applying PCA function on training 
# and testing set of X component 
from sklearn.decomposition import PCA 
  
pca = PCA(n_components = 2) 
  
#x_train = pca.fit_transform(x_train) 
#x_test = pca.transform(x_test) 
  
#explained_variance = pca.explained_variance_ratio_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-2f6a84c30d57> in <module>()
#       5 pca = PCA(n_components = 2)
#       6
# ----> 7 x_train = pca.fit_transform(x_train)
#       8 #x_test = pca.transform(x_test)
#       9
#
# ~\Anaconda3\lib\site-packages\sklearn\decomposition\pca.py in fit_transform(self, X, y)
#     346
#     347         """
# --> 348         U, S, V = self._fit(X)
#     349         U = U[:, :self.n_components_]
#     350
#
# ~\Anaconda3\lib\site-packages\sklearn\decomposition\pca.py in _fit(self, X)
#     368
#     369         X = check_array(X, dtype=[np.float64, np.float32], ensure_2d=True,
# --> 370                         copy=self.copy)
#     371
#     372         # Handle n_components==None
#
# ...
